# %%
# Made by Premysl Pilar - A01760915
# This notebook shows how succesfull are cleaning agents using random movement
# 10/11/2022
#

# %%
# !pip install mesa
# Out:
# Collecting mesa
#   Downloading Mesa-1.1.1-py3-none-any.whl (1.8 MB)
#      ---------------------------------------- 1.8/1.8 MB 2.9 MB/s eta 0:00:00
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.6/96.6 kB 2.7 MB/s eta 0:00:00
# Collecting cookiecutter
#   Downloading cookiecutter-2.1.1-py2.py3-none-any.whl (36 kB)
# Requirement already satisfied: tornado in d:\neural\venv\lib\site-packages (from mesa) (6.2)
# Collecting networkx
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy in d:\neural\venv\lib\site-packages (from mesa) (1.21.5)
# Requirement already satisfied: pandas in d:\neural\venv\lib\site-packages (from mesa) (1.2.4)
# Collecting tqdm
#   Downloading tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.5/78.5 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: colorama in d:\neural\venv\lib\site-packages (from click->mesa) (0.4.5)
# Collecting python-slugify>=4.0.0
#   Downloading python_slugify-6.1.2-py2.py3-none-any.whl (9.4 kB)
# Collecting jinja2-time>=0.2.0
#   Downloading jinja2_time-0.2.0-py2.py3-none-any.whl (6.4 kB)
# Collecting binaryornot>=0.4.4
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: requests>=2.23.0 in d:\neural\venv\lib\site-packages (from cookiecutter->mesa) (2.25.1)
# Collecting pyyaml>=5.3.1
#   Downloading PyYAML-6.0-cp39-cp39-win_amd64.whl (151 kB)
#      -------------------------------------- 151.6/151.6 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in d:\neural\venv\lib\site-packages (from cookiecutter->mesa) (3.1.2)
# Requirement already satisfied: pytz>=2017.3 in d:\neural\venv\lib\site-packages (from pandas->mesa) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\neural\venv\lib\site-packages (from pandas->mesa) (2.8.2)
# Requirement already satisfied: chardet>=3.0.2 in d:\neural\venv\lib\site-packages (from binaryornot>=0.4.4->cookiecutter->mesa) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\neural\venv\lib\site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter->mesa) (2.1.1)
# Collecting arrow
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ---------------------------------------- 66.4/66.4 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in d:\neural\venv\lib\site-packages (from python-dateutil>=2.7.3->pandas->mesa) (1.16.0)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.2/78.2 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in d:\neural\venv\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\neural\venv\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (1.26.12)
# Requirement already satisfied: idna<3,>=2.5 in d:\neural\venv\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (2.10)
# Installing collected packages: text-unidecode, tqdm, pyyaml, python-slugify, networkx, click, binaryornot, arrow, jinja2-time, cookiecutter, mesa
# Successfully installed arrow-1.2.3 binaryornot-0.4.4 click-8.1.3 cookiecutter-2.1.1 jinja2-time-0.2.0 mesa-1.1.1 networkx-2.8.8 python-slugify-6.1.2 pyyaml-6.0 text-unidecode-1.3 tqdm-4.64.1
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mesa
import matplotlib.pyplot as plt
import numpy as np

# %%
# Cleaning agent cleans the dirt agent using wealth variable.
# When dirt agent is cleaned it will change its wealth to 0.
# Agents do not colide.
# Cleaning agents move randomly.

class CleaningAgent(mesa.Agent):

    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 0

    def move(self):
        possible_steps = self.model.gridClean.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        if len(possible_steps) == 0:
            return
        new_position = self.random.choice(possible_steps)
        self.model.gridClean.move_agent(self, new_position)

    def clean(self):
        cleaned = False
        cellmates = self.model.gridDirt.get_cell_list_contents([self.pos])
        for i in cellmates:
            if i.wealth != 0:
                i.wealth = 0
                cleaned = True
        return cleaned

    # Agent can either clean or take a step
    def step(self):
        if not self.clean():
            self.move()
            
            
class DirtAgent(mesa.Agent):
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 1
    def step(self):
        pass

# %%
# Model containing 2 grids one for each type of agents.
class CleanModel(mesa.Model):
    #
    def __init__(self, numberOfCleaningAgents, percentageOfDirts, width, height):
        numberOfDirts =  int(height * width * percentageOfDirts / 100) 
        self.num_agents = numberOfCleaningAgents + numberOfDirts
        self.gridClean = mesa.space.MultiGrid(width, height, False)
        self.gridDirt = mesa.space.SingleGrid(width, height, False)
        self.schedule = mesa.time.RandomActivation(self)
        
        # Create agents
        for i in range(numberOfCleaningAgents):
            agent = CleaningAgent(i, self)
            self.schedule.add(agent)
            self.gridClean.place_agent(agent, (0, 0))

        for i in range(numberOfDirts):
            agent = DirtAgent(i+numberOfCleaningAgents, self)
            self.schedule.add(agent)
            x = self.random.randrange(width)
            y = self.random.randrange(height)
            while not self.gridDirt.is_cell_empty((x,y)):
                x = self.random.randrange(width)
                y = self.random.randrange(height)
            self.gridDirt.place_agent(agent,(x,y))
    def step(self):
        self.schedule.step()

# %%
# Given parameters
numberOfCleaningAgents = 10
percentageOfDirts=60
width=10
height=10
maxSteps = 100
sampleSize = 100
listPercentage = []
listSteps = []

# %%
# Function that initializes model with given parameters and performs the simulation
# Note it gathers the data of single steps by agents but since the tick should be "at once" it does not
# give any additional value and is calculated simply and not used further.
def testRun():
        model = CleanModel(numberOfCleaningAgents,percentageOfDirts,width,height)
        finalPercentageOfDirts = percentageOfDirts
        totalSteps = 0
        totalAgentSteps = 0
        for i in range(maxSteps):
            currentWealth = 0
            for agent in model.schedule.agents:
                currentWealth += agent.wealth
            if currentWealth == 0:
                finalPercentageOfDirts = 0
                totalSteps = i
                totalAgentSteps = i * numberOfCleaningAgents
                listPercentage.append(finalPercentageOfDirts)
                listSteps.append(totalSteps)
                return
            model.step()
            if i == maxSteps - 1:
                finalPercentageOfDirts =  100 * currentWealth / (height * width)
                totalSteps = maxSteps
                totalAgentSteps = maxSteps * numberOfCleaningAgents
                listPercentage.append(finalPercentageOfDirts)
                listSteps.append(totalSteps)

# %%
# Prints histograms from the data obtained by the simulations.
def printHistograms():
    plt.hist(x=listPercentage, bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.95)
    plt.grid(axis='y', alpha=0.75)
    plt.xlabel('Dirtiness')
    plt.ylabel('Frequency')
    plt.title('Percentages of dirty cells')
    maxfreq = n.max()
    plt.show()

    plt.hist(x=listSteps, bins= int(maxSteps/10), color='#0504aa',
                                alpha=0.7, rwidth=0.95)
    plt.grid(axis='y', alpha=0.75)
    plt.xlabel('Steps')
    plt.ylabel('Frequency')
    plt.title('Number of steps taken')
    maxfreq = n.max()
    plt.show()

# %%
# Function that simulates the model *sampleSize* times, plots the histogram of dirtiness and 
# number of steps needed.
def batch():
    for test in range(sampleSize):
        testRun()
    print("Test ended")
    printHistograms()

# %%
batch()
# Out:
# Test ended

# %%
#Now let's increase number of agents
numberOfCleaningAgents = 100
listPercentage = []
listSteps = []
batch()
# Out:
# Test ended

# %%
#Let's increase the size of the grid
width = 30
height = 30
listPercentage = []
listSteps = []
batch()
# Out:
# Test ended

# %%
#Let's increase the number of agent and maximum number of steps
numberOfCleaningAgents = 1000
maxSteps = 1000
listPercentage = []
listSteps = []
batch()
# Out:
# Test ended

# %% [markdown]
# And we could play like this for forever. The random movement is not the best choice to solve to problem but with a brute strength it can solve it. Since the movements are randomly chosen without any seed the results will differ every run. To further investigate the influence of each parameter we would need to introduce such a thing. And yet we could continue with the analysis. Simply more agents and more maximum steps better cleaning power. Bigger space and more dirt tiles less cleaning power. For the number of steps if the cleaning power was enough we can see normal distribution. For Dirtiness we can see exponentional distribution. Of course we could change the parameters more but for task this simple I think it is not that much beneficial anymore.
